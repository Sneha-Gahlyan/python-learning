# %% [markdown]
# #Arithmetic Operators

# %%
a = 12
b = 8

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)
# Out:
# Addition: 20
# Subtraction: 4
# Multiplication: 96
# Division: 1.5
# Floor Division: 1
# Modulus: 4
# Exponentiation: 429981696

# %% [markdown]
# #Assignment Operator

# %%
y = 15
print(y)
# Out:
# 15

# %% [markdown]
# #Compound Assignment Operator

# %%
x =  10

x += 5
print("Add and assign : " ,x)       # 15

x -= 3
print("Subtract and assign : ",x)       # 12

x *= 2
print("Multiply and assign",x)       # 24

x /= 4
print("Divide and assign",x)       # 6.0

x //= 5
print("Floor divide and assign",x)       # 1.0

x **= 3
print("Exponent and assign",x)       # 1.0

x %= 2
print("Modulus and assign",x)       # 1.0
# Out:
# Add and assign :  15
# Subtract and assign :  12
# Multiply and assign 24
# Divide and assign 6.0
# Floor divide and assign 1.0
# Exponent and assign 1.0
# Modulus and assign 1.0

# %% [markdown]
# #Comparision Operator

# %%
a = 10
b = 20

print("Equal to : ",a == b)
print("Not Equal to : ",a != b)
print("Greater than :",a > b)
print("Less than : ",a < b)
print("Greater than or equal to : ",a >= b)
print("Less than or equal to : ", a <= b)

print("A" > "B")
print(ord("B"))
print(ord("A"))
# Out:
# Equal to :  False
# Not Equal to :  True
# Greater than : False
# Less than :  True
# Greater than or equal to :  False
# Less than or equal to :  True
# False
# 66
# 65

# %% [markdown]
# #Logical Operators

# %%
m = 15
print(m > 10 and m < 20)
print(m > 10  or m == 80)
print(not(m > 5))
# Out:
# True
# True
# False

# %% [markdown]
# # Practise

# %%
print(126 > 130)

print((456 == 456) != (235 == 236))

print(12 < 10 or 45 == 56 or 69 > 70 or 15 != 13)

print(True and bool(0))
# Out:
# False
# True
# True
# False
