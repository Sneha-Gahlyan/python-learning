# %% [markdown]
# #Input and Output

# %% [markdown]
# #Output
# #*Basic print()

# %%
print("Hello,Welcome to my Python learning repository")
# Out:
# Hello,Welcome to my Python learning repository

# %% [markdown]
# #*Printing Variables

# %%
name = "Sneha"
batch = 2027
print(name)
print(batch)
# Out:
# Sneha
# 2027

# %% [markdown]
# #*Formatted Strings (f-strings)

# %%
name = "Sneha"
age = 21

# Without f-string
print("My name is " + name + " and I am " + str(age) + " years old.")

# With f-string
message = f"My name is {name} and I am {age} years old."

print(message)
# Out:
# My name is Sneha and I am 21 years old.
# My name is Sneha and I am 21 years old.

# %% [markdown]
# #Input

# %%
# Enter your name
name = input("Enter your name: ")
print("Hello, " + name )

# Enter your age
age = int(input("Enter your age: "))
print(age)
print(name + " is " + str(age) + " years old.")

#Enter Marks
marks = float(input("Enter your marks: "))
print(name + " scored " + str(marks) + " marks.")
# Out:
# Enter your name: sneha
# Hello, sneha
# Enter your age: 22
# 22
# sneha is 22 years old.
# Enter your marks: 45.5
# sneha scored 45.5 marks.
