# %% [markdown]
# #Practice Conditionals

# %%
#Q1. Accept two numbers and print the greatest between them.
number1 = int(input("Enter first number: "))
number2 = int(input("Enter second number: "))

if number1 > number2:
  print(f" {number1} is greater than {number2}")
elif number2 > number1:
  print(f" {number2} is greater than {number1}")
else:
  print("Both numbers are equal")
# Out:
# Enter first number: 45.5
# Enter second number: 3
# 45.5 is greater

# %%
#Q2. Accept the gender from the user as char and print the
#respective greeting message
#Ex - Good Morning Sir (on the basis of gender)

gender = input("Enter the gender male or female or other as character:")

if gender == "M" or gender == "m":
  print("Good Morning Sir")
elif gender == "F" or gender == "f":
  print("Good Morning Ma'am")
else:
  print("Good Morning")
# Out:
# Enter the gender male or female or others:male
# Good Morning Sir

# %%
#Q3. Accept an integer and check whether it is an even number or odd.
num = int(input("Enter a number:"))
if(num % 2) == 0 :
  print("even number")
else :
  print("odd number")
# Out:
# Enter a number:78
# even number

# %%
# Q4. Accept name and age from the user. Check if the user is a valid voter or not.
# Ex- “hello shery you are a valid voter”
name = input("Enter your name:")
age = int(input("Enter your age:"))
if age >= 18:
  print(f"Hello {name} you are a valid voter")
else:
  print(f"Hello {name} you are not a valid voter , You can vote after {18-age} years ")
# Out:
# Enter your name:sneha
# Enter your age:16
# Hello sneha you are not a valid voter , You can vote after 2 years

# %%
# Q5. Accept a year and check if it a leap year or not (google to
# find out what is a leap year)

year = int(input("Enter a year : "))

if year % 100 == 0  and year % 400 ==0 :
  print(f"{year} is a leap year ")
elif year % 100 != 0 and year % 4 ==0 :
  print(f"{year} is a leap year ")
else :
  print("its an normal year ")
# Out:
# Enter a year : 2024
# 2024 is a leap year

# %%
# Q6. elif ladder : You cna also create if elif ladder using multiple conditions of elif
# take the input of temperature in celsiusX
# Below 0°C → "Freezing Cold   ,    0°C to 10°C → "Very Cold
# 10°C to 20°C → "Cold         ,    20°C to 30°C → "Pleasant
# 30°C to 40°C → "Hot          ,    Above 40°C → "Very Hot "

t = int(input("Please Enter temperature in celcius: "))

if t<0 :
  print("Freezing Cold ")
elif t>=0 and t<10 :
  print("Very Cold ")
elif t>=10 and t<20 :
  print("Cold ")
elif t>=20 and t<30 :
  print("Pleasant ")
elif t>=30 and t<40 :
  print("Hot ")
else :
  print("Temperature is very hot")
# Out:
# Please Enter temperature in celcius: 3
# Very Cold
