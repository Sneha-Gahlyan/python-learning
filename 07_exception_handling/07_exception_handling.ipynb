# %% [markdown]
# #Exception handling

# %%
# Error : Errors occur due to mistakes in the code that prevent it from
# running. These can be syntax errors or logical errors6

# 1. syntax error
# 2. Indentation error
# 3. Tab error

# %% [markdown]
# #Exceptions

# %%
# Exceptions are unexpected events or errors that occurs
# during the execution of a program, which disrupts the normal
# flow of the program

# --------------------------------------------------
# 1. try and except
# --------------------------------------------------

try:
    num = int(input("Enter a number: "))
    print(10 / num)
except:
    print("Something went wrong")
# Out:
# Enter a number: 0
# Something went wrong

# %%
# --------------------------------------------------
# 2. Handling specific exceptions
# --------------------------------------------------

try:
    num = int(input("Enter a number: "))
    print(10/num)

except ZeroDivisionError  :
    print("Cannot divide by zero")
# Out:
# Enter a number: 0
# Cannot divide by zero

# %%
# --------------------------------------------------
# 3. Handling specific exceptions
# --------------------------------------------------

try:
    num = int(input("Enter a number: "))
    print(10/num)

except Exception as err  :
    print(f"Sorry there is an error as {err}")
# Out:
# Enter a number: Sneha
# Sorry there is an error as invalid literal for int() with base 10: 'Sneha'

# %%
# --------------------------------------------------
# 4. else
# --------------------------------------------------

try:
    num = int(input("Enter a number: "))
    result = (10/num)

except Exception as err  :
    print(f"Sorry there is an error as {err}")

else:
    print(f"Result : {result}\nThere is no exception")
# Out:
# Enter a number: 5
# Result : 2.0
# There is no exception

# %%
# --------------------------------------------------
# 5. finally
# --------------------------------------------------

try:
    num = int(input("Enter a number: "))
    result = (10/num)

except Exception as err  :
    print(f"Sorry there is an error as {err}")

finally :
    print("This block always executes.")
# Out:
# Enter a number: 0
# Sorry there is an error as division by zero
# This block always executes.

# %%
# --------------------------------------------------
# 6. raise
# --------------------------------------------------

age = int(input("Enter your age: "))

try:
  if age < 0:
    raise ValueError("Age can't be negative")
  else:
    print("Welcome!")

except Exception as err:
  print(f"An error occured as {err}")
# Out:
# Enter your age: -1
# An error occured as Age can't be negative
