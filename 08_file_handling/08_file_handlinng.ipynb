# %%
r = open("super.txt",'w')
r.write("hello this file handling")


r.close()

# %%
m = open("super.txt" , 'r')
content = m.read()
print(content)
m.close()
# Out:
# hello this file handling

# %% [markdown]
# With Keyword

# %%
with open("super.txt" , 'r') as f:
  content = f.read()
  print(content)
# Out:
# hello this file handling
